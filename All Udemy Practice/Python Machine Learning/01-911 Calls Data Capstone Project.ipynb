# %% [markdown]
# # 911 Calls Capstone Project

# %% [markdown]
# For this capstone project we will be analyzing some 911 call data from [Kaggle](https://www.kaggle.com/mchirico/montcoalert). The data contains the following fields:
#
# * lat : String variable, Latitude
# * lng: String variable, Longitude
# * desc: String variable, Description of the Emergency Call
# * zip: String variable, Zipcode
# * title: String variable, Title
# * timeStamp: String variable, YYYY-MM-DD HH:MM:SS
# * twp: String variable, Township
# * addr: String variable, Address
# * e: String variable, Dummy variable (always 1)
#
# Just go along with this notebook and try to complete the instructions or answer the questions in bold using your Python and Data Science skills!

# %% [markdown]
# ## Data and Setup

# %% [markdown]
# ____
# ** Import numpy and pandas **

# %%
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ** Import visualization libraries and set %matplotlib inline. **

# %%
import seaborn as sns

# %% [markdown]
# ** Read in the csv file as a dataframe called df **

# %%
df=pd.read_csv('911.csv')

# %% [markdown]
# ** Check the info() of the df **

# %%
df.info
# Out:
# <bound method DataFrame.info of              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# 99489  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...  19401.0
# 99490  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...  19002.0
# 99491  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...  19446.0
#
#                              title            timeStamp                twp  \
# 0           EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1          EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2              Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3           EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4                   EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
# ...                            ...                  ...                ...
# 99487  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:06:00         NORRISTOWN
# 99488  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:07:02       LOWER MERION
# 99489             EMS: FALL VICTIM  2016-08-24 11:12:00         NORRISTOWN
# 99490         EMS: NAUSEA/VOMITING  2016-08-24 11:17:01            HORSHAM
# 99491  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:17:02      UPPER GWYNEDD
#
#                                  addr  e
# 0              REINDEER CT & DEAD END  1
# 1          BRIAR PATH & WHITEMARSH LN  1
# 2                            HAWS AVE  1
# 3                  AIRY ST & SWEDE ST  1
# 4            CHERRYWOOD CT & DEAD END  1
# ...                               ... ..
# 99487         MARKLEY ST & W LOGAN ST  1
# 99488  LANCASTER AVE & RITTENHOUSE PL  1
# 99489         CHESTNUT ST & WALNUT ST  1
# 99490           WELSH RD & WEBSTER LN  1
# 99491          MORRIS RD & S BROAD ST  1
#
# [99492 rows x 9 columns]>

# %% [markdown]
# ** Check the head of df **

# %%
df.head(5)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1
# 3          AIRY ST & SWEDE ST  1
# 4    CHERRYWOOD CT & DEAD END  1

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# ** What are the top 5 zipcodes for 911 calls? **

# %%
df["zip"].value_counts().head(5)
# Out:
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: zip, dtype: int64

# %% [markdown]
# ** What are the top 5 townships (twp) for 911 calls? **

# %%
df["twp"].value_counts().head(5)
# Out:
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: twp, dtype: int64

# %% [markdown]
# ** Take a look at the 'title' column, how many unique title codes are there? **

# %%
#110

len(df["title"].value_counts())
# Out:
# 110

# %% [markdown]
# ## Creating new features

# %% [markdown]
# ** In the titles column there are "Reasons/Departments" specified before the title code. These are EMS, Fire, and Traffic. Use .apply() with a custom lambda expression to create a new column called "Reason" that contains this string value.**
#
# **For example, if the title column value is EMS: BACK PAINS/INJURY , the Reason column value would be EMS. **

# %%
df["Reason"]=df['title'].apply(lambda x: x.split()[0] )
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# 99489  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...  19401.0
# 99490  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...  19002.0
# 99491  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...  19446.0
#
#                              title            timeStamp                twp  \
# 0           EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1          EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2              Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3           EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4                   EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
# ...                            ...                  ...                ...
# 99487  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:06:00         NORRISTOWN
# 99488  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:07:02       LOWER MERION
# 99489             EMS: FALL VICTIM  2016-08-24 11:12:00         NORRISTOWN
# 99490         EMS: NAUSEA/VOMITING  2016-08-24 11:17:01            HORSHAM
# 99491  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:17:02      UPPER GWYNEDD
#
#                                  addr  e    Reason
# 0              REINDEER CT & DEAD END  1      EMS:
# 1          BRIAR PATH & WHITEMARSH LN  1      EMS:
# 2                            HAWS AVE  1     Fire:
# 3                  AIRY ST & SWEDE ST  1      EMS:
# 4            CHERRYWOOD CT & DEAD END  1      EMS:
# ...                               ... ..       ...
# 99487         MARKLEY ST & W LOGAN ST  1  Traffic:
# 99488  LANCASTER AVE & RITTENHOUSE PL  1  Traffic:
# 99489         CHESTNUT ST & WALNUT ST  1      EMS:
# 99490           WELSH RD & WEBSTER LN  1      EMS:
# 99491          MORRIS RD & S BROAD ST  1  Traffic:
#
# [99492 rows x 10 columns]

# %% [markdown]
# ** What is the most common Reason for a 911 call based off of this new column? **

# %%
#EMS        48877
#Traffic    35695
#Fire       14920

df["Reason"].value_counts().head(3)
# Out:
# EMS:        48877
# Traffic:    35695
# Fire:       14920
# Name: Reason, dtype: int64

# %% [markdown]
# ** Now use seaborn to create a countplot of 911 calls by Reason. **

# %%
sns.countplot(df['Reason'])

# %% [markdown]
# ___
# ** Now let us begin to focus on time information. What is the data type of the objects in the timeStamp column? **

# %%
type(df['timeStamp'].iloc[0])
# Out:
# str

# %% [markdown]
# ** You should have seen that these timestamps are still strings. Use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) to convert the column from strings to DateTime objects. **

# %%
#pd.to_datetime(df['timeStamp'])
#pd.to_datetime(df['timeStamp'].iloc[0])

df["timeStamp"]= pd.to_datetime(df["timeStamp"]) 
type(df['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ** You can now grab specific attributes from a Datetime object by calling them. For example:**
#
#     time = df['timeStamp'].iloc[0]
#     time.hour
#
# **You can use Jupyter's tab method to explore the various attributes you can call. Now that the timestamp column are actually DateTime objects, use .apply() to create 3 new columns called Hour, Month, and Day of Week. You will create these columns based off of the timeStamp column, reference the solutions if you get stuck on this step.**

# %%
time=df['timeStamp'].iloc[0]
#time_string=time.split('-')
df['Hour']=df["timeStamp"].apply(lambda x: x.hour)
df['Month']=df["timeStamp"].apply(lambda x: x.month)
df["Day of Week"]=df["timeStamp"].apply(lambda x: x.dayofweek)
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# 99489  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...  19401.0
# 99490  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...  19002.0
# 99491  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...  19446.0
#
#                              title           timeStamp                twp  \
# 0           EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1          EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2              Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3           EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4                   EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
# ...                            ...                 ...                ...
# 99487  Traffic: VEHICLE ACCIDENT - 2016-08-24 11:06:00         NORRISTOWN
# 99488  Traffic: VEHICLE ACCIDENT - 2016-08-24 11:07:02       LOWER MERION
# 99489             EMS: FALL VICTIM 2016-08-24 11:12:00         NORRISTOWN
# 99490         EMS: NAUSEA/VOMITING 2016-08-24 11:17:01            HORSHAM
# 99491  Traffic: VEHICLE ACCIDENT - 2016-08-24 11:17:02      UPPER GWYNEDD
#
#                                  addr  e    Reason  Hour  Month  Day of Week
# 0              REINDEER CT & DEAD END  1      EMS:    17     12            3
# 1          BRIAR PATH & WHITEMARSH LN  1      EMS:    17     12            3
# 2                            HAWS AVE  1     Fire:    17     12            3
# 3                  AIRY ST & SWEDE ST  1      EMS:    17     12            3
# 4            CHERRYWOOD CT & DEAD END  1      EMS:    17     12            3
# ...                               ... ..       ...   ...    ...          ...
# 99487         MARKLEY ST & W LOGAN ST  1  Traffic:    11      8            2
# 99488  LANCASTER AVE & RITTENHOUSE PL  1  Traffic:    11      8            2
# 99489         CHESTNUT ST & WALNUT ST  1      EMS:    11      8            2
# 99490           WELSH RD & WEBSTER LN  1      EMS:    11      8            2
# 99491          MORRIS RD & S BROAD ST  1  Traffic:    11      8            2
#
# [99492 rows x 13 columns]

# %% [markdown]
# ** Notice how the Day of Week is an integer 0-6. Use the .map() with this dictionary to map the actual string names to the day of the week: **
#
#     dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

df['Day of Week'] = df['Day of Week'].map(dmap)

# %%
df

# %% [markdown]
# ** Now use seaborn to create a countplot of the Day of Week column with the hue based off of the Reason column. **

# %%
 
# count plot on single categorical variable
sns.countplot(x ='Day of Week', hue="Reason", data = df)
 
# Show the plot
plt.show()

# %% [markdown]
# **Now do the same for Month:**

# %%
 
# count plot on single categorical variable
sns.countplot(x ='Month', hue="Reason", data = df)
 
# Show the plot
plt.show()

# %% [markdown]
# **Did you notice something strange about the Plot?**
#
# _____
#
# ** You should have noticed it was missing some Months, let's see if we can maybe fill in this information by plotting the information in another way, possibly a simple line plot that fills in the missing months, in order to do this, we'll need to do some work with pandas... **

# %% [markdown]
# ** Now create a gropuby object called byMonth, where you group the DataFrame by the month column and use the count() method for aggregation. Use the head() method on this returned DataFrame. **

# %%
byMonth=df.groupby("Month").count().head(5)
byMonth
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      13205  13205  13205  11527  13205      13205  13203  13096  13205
# 2      11467  11467  11467   9930  11467      11467  11465  11396  11467
# 3      11101  11101  11101   9755  11101      11101  11092  11059  11101
# 4      11326  11326  11326   9895  11326      11326  11323  11283  11326
# 5      11423  11423  11423   9946  11423      11423  11420  11378  11423
#
#        Reason   Hour  Day of Week
# Month
# 1       13205  13205        13205
# 2       11467  11467        11467
# 3       11101  11101        11101
# 4       11326  11326        11326
# 5       11423  11423        11423

# %% [markdown]
# ** Now create a simple plot off of the dataframe indicating the count of calls per month. **

# %%
byMonth['twp'].plot()

# %% [markdown]
# ** Now see if you can use seaborn's lmplot() to create a linear fit on the number of calls per month. Keep in mind you may need to reset the index to a column. **

# %%
sns.lmplot(x='Month',y='twp',data=byMonth.reset_index())

# %% [markdown]
# **Create a new column called 'Date' that contains the date from the timeStamp column. You'll need to use apply along with the .date() method. **

# %%
df["Date"]=df['timeStamp'].apply(lambda x: x.date())

# %% [markdown]
# ** Now groupby this Date column with the count() aggregate and create a plot of counts of 911 calls.**

# %%
byDate=df.groupby("Date").count()
byDate
# count plot on single categorical variable
sns.countplot(x =byDate["twp"], data = df)
 
# Show the plot
#plt.show()

# %% [markdown]
# ** Now recreate this plot but create 3 separate plots with each plot representing a Reason for the 911 call**

# %%
df['EMS']=df['Reason'].apply(lambda x: x)=='EMS:'

sns.countplot(x="EMS", data = df)

# %%
df['Fire']=df['Reason'].apply(lambda x: x)=='Fire:'

sns.countplot(x="Fire", data = df)

# %%
df['Traffic']=df['Reason'].apply(lambda x: x)=='Traffic:'

sns.countplot(x="Traffic", data = df)

# %% [markdown]
# ____
# ** Now let's move on to creating  heatmaps with seaborn and our data. We'll first need to restructure the dataframe so that the columns become the Hours and the Index becomes the Day of the Week. There are lots of ways to do this, but I would recommend trying to combine groupby with an [unstack](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html) method. Reference the solutions if you get stuck on this!**

# %%
df_t=df.transpose()
df_t
# Out:
#                                                          0      \
# lat                                                    40.2979
# lng                                                   -75.5813
# desc         REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# zip                                                      19525
# title                                   EMS: BACK PAINS/INJURY
# timeStamp                                  2015-12-10 17:40:00
# twp                                                NEW HANOVER
# addr                                    REINDEER CT & DEAD END
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          1      \
# lat                                                    40.2581
# lng                                                   -75.2647
# desc         BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# zip                                                      19446
# title                                  EMS: DIABETIC EMERGENCY
# timeStamp                                  2015-12-10 17:40:00
# twp                                          HATFIELD TOWNSHIP
# addr                                BRIAR PATH & WHITEMARSH LN
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          2      \
# lat                                                    40.1212
# lng                                                    -75.352
# desc         HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# zip                                                      19401
# title                                      Fire: GAS-ODOR/LEAK
# timeStamp                                  2015-12-10 17:40:00
# twp                                                 NORRISTOWN
# addr                                                  HAWS AVE
# e                                                            1
# Reason                                                   Fire:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                      False
# Fire                                                      True
# Traffic                                                  False
#
#                                                          3      \
# lat                                                    40.1162
# lng                                                   -75.3435
# desc         AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# zip                                                      19401
# title                                   EMS: CARDIAC EMERGENCY
# timeStamp                                  2015-12-10 17:40:01
# twp                                                 NORRISTOWN
# addr                                        AIRY ST & SWEDE ST
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          4      \
# lat                                                    40.2515
# lng                                                   -75.6033
# desc         CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# zip                                                        NaN
# title                                           EMS: DIZZINESS
# timeStamp                                  2015-12-10 17:40:01
# twp                                           LOWER POTTSGROVE
# addr                                  CHERRYWOOD CT & DEAD END
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          5      \
# lat                                                    40.2535
# lng                                                   -75.2832
# desc         CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# zip                                                      19446
# title                                         EMS: HEAD INJURY
# timeStamp                                  2015-12-10 17:40:01
# twp                                                   LANSDALE
# addr                                     CANNON AVE & W 9TH ST
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          6      \
# lat                                                    40.1821
# lng                                                   -75.1278
# desc         LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# zip                                                      19044
# title                                     EMS: NAUSEA/VOMITING
# timeStamp                                  2015-12-10 17:40:01
# twp                                                    HORSHAM
# addr                                  LAUREL AVE & OAKDALE AVE
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          7      \
# lat                                                    40.2173
# lng                                                   -75.4052
# desc         COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# zip                                                      19426
# title                               EMS: RESPIRATORY EMERGENCY
# timeStamp                                  2015-12-10 17:40:01
# twp                                                   SKIPPACK
# addr                              COLLEGEVILLE RD & LYWISKI RD
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          8      \
# lat                                                     40.289
# lng                                                   -75.3996
# desc         MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# zip                                                      19438
# title                                    EMS: SYNCOPAL EPISODE
# timeStamp                                  2015-12-10 17:40:01
# twp                                              LOWER SALFORD
# addr                             MAIN ST & OLD SUMNEYTOWN PIKE
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        17
# Month                                                       12
# Day of Week                                                Thu
# Date                                                2015-12-10
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          9      ...  \
# lat                                                    40.1024  ...
# lng                                                   -75.2915  ...
# desc         BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...  ...
# zip                                                      19462  ...
# title                              Traffic: VEHICLE ACCIDENT -  ...
# timeStamp                                  2015-12-10 17:40:01  ...
# twp                                                   PLYMOUTH  ...
# addr                  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  ...
# e                                                            1  ...
# Reason                                                Traffic:  ...
# Hour                                                        17  ...
# Month                                                       12  ...
# Day of Week                                                Thu  ...
# Date                                                2015-12-10  ...
# EMS                                                      False  ...
# Fire                                                     False  ...
# Traffic                                                   True  ...
#
#                                                          99482  \
# lat                                                    40.3401
# lng                                                   -75.5917
# desc         RT100 SB & E PHILADELPHIA AVE OVERPASS; DOUGLA...
# zip                                                        NaN
# title                              Traffic: DISABLED VEHICLE -
# timeStamp                                  2016-08-24 10:52:03
# twp                                                   DOUGLASS
# addr                    RT100 SB & E PHILADELPHIA AVE OVERPASS
# e                                                            1
# Reason                                                Traffic:
# Hour                                                        10
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                      False
# Fire                                                     False
# Traffic                                                   True
#
#                                                          99483  \
# lat                                                    40.0845
# lng                                                   -75.3902
# desc         DEKALB PIKE & KING OF PRUSSIA RD;  UPPER MERIO...
# zip                                                      19406
# title                                   EMS: BACK PAINS/INJURY
# timeStamp                                  2016-08-24 10:57:00
# twp                                               UPPER MERION
# addr                          DEKALB PIKE & KING OF PRUSSIA RD
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        10
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          99484  \
# lat                                                     40.133
# lng                                                   -75.4085
# desc         SHANNONDELL DR & SHANNONDELL BLVD; LOWER PROVI...
# zip                                                      19403
# title                                         Fire: FIRE ALARM
# timeStamp                                  2016-08-24 10:57:00
# twp                                           LOWER PROVIDENCE
# addr                         SHANNONDELL DR & SHANNONDELL BLVD
# e                                                            1
# Reason                                                   Fire:
# Hour                                                        10
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                      False
# Fire                                                      True
# Traffic                                                  False
#
#                                                          99485  \
# lat                                                    40.1436
# lng                                                   -75.4279
# desc         EAGLEVILLE RD & REDTAIL RD; LOWER PROVIDENCE; ...
# zip                                                      19403
# title                              Traffic: DISABLED VEHICLE -
# timeStamp                                  2016-08-24 10:57:01
# twp                                           LOWER PROVIDENCE
# addr                                EAGLEVILLE RD & REDTAIL RD
# e                                                            1
# Reason                                                Traffic:
# Hour                                                        10
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                      False
# Fire                                                     False
# Traffic                                                   True
#
#                                                          99486  \
# lat                                                    40.1792
# lng                                                   -75.1806
# desc         WELSH RD & NORRISTOWN RD; HORSHAM; 2016-08-24 ...
# zip                                                      19044
# title                              Traffic: VEHICLE ACCIDENT -
# timeStamp                                  2016-08-24 11:02:02
# twp                                                    HORSHAM
# addr                                  WELSH RD & NORRISTOWN RD
# e                                                            1
# Reason                                                Traffic:
# Hour                                                        11
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                      False
# Fire                                                     False
# Traffic                                                   True
#
#                                                          99487  \
# lat                                                    40.1329
# lng                                                   -75.3335
# desc         MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...
# zip                                                      19401
# title                              Traffic: VEHICLE ACCIDENT -
# timeStamp                                  2016-08-24 11:06:00
# twp                                                 NORRISTOWN
# addr                                   MARKLEY ST & W LOGAN ST
# e                                                            1
# Reason                                                Traffic:
# Hour                                                        11
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                      False
# Fire                                                     False
# Traffic                                                   True
#
#                                                          99488  \
# lat                                                     40.007
# lng                                                   -75.2891
# desc         LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...
# zip                                                      19003
# title                              Traffic: VEHICLE ACCIDENT -
# timeStamp                                  2016-08-24 11:07:02
# twp                                               LOWER MERION
# addr                            LANCASTER AVE & RITTENHOUSE PL
# e                                                            1
# Reason                                                Traffic:
# Hour                                                        11
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                      False
# Fire                                                     False
# Traffic                                                   True
#
#                                                          99489  \
# lat                                                    40.1154
# lng                                                   -75.3347
# desc         CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...
# zip                                                      19401
# title                                         EMS: FALL VICTIM
# timeStamp                                  2016-08-24 11:12:00
# twp                                                 NORRISTOWN
# addr                                   CHESTNUT ST & WALNUT ST
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        11
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          99490  \
# lat                                                    40.1864
# lng                                                   -75.1926
# desc         WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...
# zip                                                      19002
# title                                     EMS: NAUSEA/VOMITING
# timeStamp                                  2016-08-24 11:17:01
# twp                                                    HORSHAM
# addr                                     WELSH RD & WEBSTER LN
# e                                                            1
# Reason                                                    EMS:
# Hour                                                        11
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                       True
# Fire                                                     False
# Traffic                                                  False
#
#                                                          99491
# lat                                                    40.2071
# lng                                                    -75.318
# desc         MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...
# zip                                                      19446
# title                              Traffic: VEHICLE ACCIDENT -
# timeStamp                                  2016-08-24 11:17:02
# twp                                              UPPER GWYNEDD
# addr                                    MORRIS RD & S BROAD ST
# e                                                            1
# Reason                                                Traffic:
# Hour                                                        11
# Month                                                        8
# Day of Week                                                Wed
# Date                                                2016-08-24
# EMS                                                      False
# Fire                                                     False
# Traffic                                                   True
#
# [17 rows x 99492 columns]

# %% [markdown]
# **Continue exploring the Data however you see fit!**
# # Great Job!
